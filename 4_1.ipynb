# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_4_Functions/blob/main/4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Напишите функцию message(), которая в качестве своего параметра считывает имя и фамилию,
# записанные в одну строку через пробел, и возвращает сообщение:

def message(name):
    return f'Уважаемый, {name}! Вы верно выполнили это задание!'
